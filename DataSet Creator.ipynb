# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv('https://raw.githubusercontent.com/reisanar/datasets/master/Amtrak.csv').to_csv('Amtrak.csv',index=False)

# %%
dic={
    'Cherry':np.random.randint(5000,50000,3600),
    'Mango':np.random.randint(5000,50000,3600),
    'Banana':np.random.randint(500,50000,3600),
    'Mango':np.random.randint(5000,50000,3600),
    'Guava':np.random.randint(5000,50000,3600),
    'Litchi':np.random.randint(5000,50000,3600),
    'Wastage':np.random.randint(5000,50000,3600)
}

# %%
pd.DataFrame(dic).to_csv("Fruits.csv")

# %%
df.h
# Out:
#    Unnamed: 0  Cherry  Mango  Banana  Guava  Litchi  Wastage
# 0           0   30153  45568   42342  23946   15399    19466
# 1           1   13003  29345   34255  19097   34973     7116
# 2           2    6619  12263    2710   6462    7689    25064
# 3           3   32956  32519    1548  45711   35422    19784
# 4           4   42122  16142   37817  42599   10118    44063

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df=pd.read_csv('Fruits.csv',index_col=0)
df.describe()
# Out:
#              Cherry         Mango        Banana         Guava        Litchi  \
# count   3600.000000   3600.000000   3600.000000   3600.000000   3600.000000
# mean   27507.025278  27892.500833  25639.677222  27384.443889  27591.676111
# std    13115.109009  12812.370523  14458.840672  12940.840518  13072.084965
# min     5004.000000   5000.000000    503.000000   5010.000000   5000.000000
# 25%    16006.750000  17090.500000  13371.250000  16225.000000  15993.000000
# 50%    27648.500000  28000.500000  25587.000000  27236.500000  27870.500000
# 75%    38755.000000  38884.000000  38476.250000  38648.250000  39195.500000
# max    49996.000000  49998.000000  49979.000000  49981.000000  49997.000000
#
#             Wastage
# count   3600.000000
# mean   27620.126944
# std    12960.889414
# min     5006.000000
# 25%    16431.750000
# 50%    27907.000000
# 75%    38901.500000
# max    49985.000000

# %%
df.to_csv('Fruits.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3600 entries, 0 to 3599
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Cherry   3600 non-null   int64
#  1   Mango    3600 non-null   int64
#  2   Banana   3600 non-null   int64
#  3   Guava    3600 non-null   int64
#  4   Litchi   3600 non-null   int64
#  5   Wastage  3600 non-null   int64
# dtypes: int64(6)
# memory usage: 196.9 KB

# %%
df.hist(color='g')
plt.tight_layout()
plt.savefig('Fruits.jpg')
plt.show()
